# %%
# !pip install Twython
import pandas as pd
import numpy as np 
from twython import Twython

CONSUMER_KEY = "Uv3Ccd0oSCf9LgawJx12EAqYl"
CONSUMER_SECRET = "NdsEcNJvTIhBVD8ApxthiidqxuY8MdKzmzPyb1tLdWCSDvLhW4"
OAUTH_TOKEN = "469275739-tpD9kkY4CCl2r8IZ2CimxNuF9DiEGtdb0fKwWLBK"
OAUTH_TOKEN_SECRET = "3Fx1ECS8mv4feMg6vfHsnFTGE5ExV845QHLPIgHuZOKF4"
twitter = Twython(
    CONSUMER_KEY, CONSUMER_SECRET,
    OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
language = "el"

# %%
tweetsPutin = []
MAX_ATTEMPTS = 40
COUNT_OF_TWEETS_TO_BE_FETCHED = 4000 


for i in range(0,MAX_ATTEMPTS):

    if(COUNT_OF_TWEETS_TO_BE_FETCHED < len(tweetsPutin)):
        print("We Got ", len(tweetsPutin), " tweets!!!")
        break 

    if(0 == i): 
        results = twitter.search(q="Πούτιν",count='100')
        print("I Got:", len(results['statuses']), " tweets")
    else:
        results = twitter.search(q="Πούτιν",count='100', include_entities='true',max_id=next_max_id)
        print("I Got:", len(results['statuses']), " tweets")


    for result in results['statuses']:
        tweetsPutin.append(result)

    try:
        next_results_url_params = results['search_metadata']['next_results']
        next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
    except:
        break
# Out:
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets

# %%
len(tweetsPutin)
# Out:
# 4000

# %%
results['search_metadata']
# Out:
# {'completed_in': 0.131,
#  'count': 100,
#  'max_id': 1537819113174749185,
#  'max_id_str': '1537819113174749185',
#  'next_results': '?max_id=1537806223625670656&q=%CE%A0%CE%BF%CF%8D%CF%84%CE%B9%CE%BD&count=100&include_entities=1',
#  'query': '%CE%A0%CE%BF%CF%8D%CF%84%CE%B9%CE%BD',
#  'refresh_url': '?since_id=1537819113174749185&q=%CE%A0%CE%BF%CF%8D%CF%84%CE%B9%CE%BD&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
tweetsPutin[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Jun 20 15:10:12 +0000 2022',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 1052877677605134336,
#     'id_str': '1052877677605134336',
#     'indices': [3, 19],
#     'name': 'Καθίκι',
#     'screen_name': 'KYTKYTKYTKYTKYT'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1538902041753489409,
#  'id_str': '1538902041753489409',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'el',
#  'metadata': {'iso_language_code': 'el', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 16,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jun 20 13:30:26 +0000 2022',
#   'entities': {'hashtags': [],
# ...

# %%
for tweet in tweetsPutin:
    print(tweet['created_at'],tweet['text'])
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
# Αλλά ο Μπόρις θέλει να τιμωρήσει τον Πούτιν οπότε ΟΚ.
# Mon Jun 20 04:52:54 +0000 2022 RT @KYTKYTKYTKYTKYT: Ποροσένκο επεισόδιο Νο2:"Ο Ποροσένκο παραδέχτηκε ότι οι συμφωνίες του Μινσκ δεν σήμαιναν τίποτα για το Κίεβο,απλώς του…
# Mon Jun 20 04:52:23 +0000 2022 RT @ManosVoularinos: Νίκη του Πούτιν στις γαλλικές εκλογές. Πανηγυρίζουν οι άνθρωποι του σε όλο τον κόσμο.
# Mon Jun 20 04:47:28 +0000 2022 RT @VjGQhWS2vjTe2j1: Bloomberg: Ο Πούτιν μπορεί να κερδίσει στην Ουκρανία -Αλλά ο πραγματικός πόλεμος αρχίζει τώρα https://t.co/mB7cOR9fey
# Mon Jun 20 04:42:26 +0000 2022 RT @ManosVoularinos: Νίκη του Πούτιν στις γαλλικές εκλογές. Πανηγυρίζουν οι άνθρωποι του σε όλο τον κόσμο.
# Mon Jun 20 04:29:26 +0000 2022 @commonsense491 Κατι ηξερε λοιπόν ο μανολο που εκανε κοκοκο στον Πουτιν τοσο καιρο. Ηξερε τι ειχε να περιμένει στο εσωτερικο.
# ...

# %%
tweetsPutin_df = pd.DataFrame(tweetsPutin)
tweetsPutin_df.head(5)
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Jun 20 15:10:12 +0000 2022  1538902041753489409  1538902041753489409
# 1  Mon Jun 20 15:09:49 +0000 2022  1538901941891305472  1538901941891305472
# 2  Mon Jun 20 15:09:23 +0000 2022  1538901835817394177  1538901835817394177
# 3  Mon Jun 20 15:08:19 +0000 2022  1538901564923990023  1538901564923990023
# 4  Mon Jun 20 15:07:49 +0000 2022  1538901441259126785  1538901441259126785
#
#                                                 text  truncated  \
# 0  RT @KYTKYTKYTKYTKYT: ΑΠΙΣΤΕΥΤΟ βίντεο, η...κ. ...      False
# 1  RT @GiannesT1: #Ρωσια #ΚΚΡΟ \nΑκύρωση περιφερε...      False
# 2  #Ρωσια #ΚΚΡΟ \nΑκύρωση περιφερειακών εκλογών σ...       True
# 3  RT @GiannesT1: #Ρωσια\nΚάθε φορά που ο λαός βγ...      False
# 4  #Ρωσια\nΚάθε φορά που ο λαός βγαίνει στους δρό...       True
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
file_name = "Final_Tweets_about_Putin"

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
tweetsPutin_df.to_csv(f"/content/gdrive/My Drive/Colab Notebooks/Final_Tweets_about_Putin.tsv", sep='\t')

# %%
tweetsZelensky = []
MAX_ATTEMPTS = 40
COUNT_OF_TWEETS_TO_BE_FETCHED = 4000 


for i in range(0,MAX_ATTEMPTS):

    if(COUNT_OF_TWEETS_TO_BE_FETCHED < len(tweetsZelensky)):
        print("We Got ", len(tweetsZelensky), " tweets!!!")
        break 

    if(0 == i): 
        results = twitter.search(q="Ζελένσκι",count='100')
        print("I Got:", len(results['statuses']), " tweets")
    else:
        results = twitter.search(q="Ζελένσκι",count='100', include_entities='true',max_id=next_max_id)
        print("I Got:", len(results['statuses']), " tweets")


    for result in results['statuses']:
        tweetsZelensky.append(result)

    try:
        next_results_url_params = results['search_metadata']['next_results']
        next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
    except:
        break
# Out:
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets

# %%
len(tweetsZelensky)
# Out:
# 4000

# %%
results['search_metadata']
# Out:
# {'completed_in': 0.179,
#  'count': 100,
#  'max_id': 1535709825128140806,
#  'max_id_str': '1535709825128140806',
#  'next_results': '?max_id=1535620046172655615&q=%CE%96%CE%B5%CE%BB%CE%AD%CE%BD%CF%83%CE%BA%CE%B9&count=100&include_entities=1',
#  'query': '%CE%96%CE%B5%CE%BB%CE%AD%CE%BD%CF%83%CE%BA%CE%B9',
#  'refresh_url': '?since_id=1535709825128140806&q=%CE%96%CE%B5%CE%BB%CE%AD%CE%BD%CF%83%CE%BA%CE%B9&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
tweetsZelensky[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Jun 20 15:21:34 +0000 2022',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 1052877677605134336,
#     'id_str': '1052877677605134336',
#     'indices': [3, 19],
#     'name': 'Καθίκι',
#     'screen_name': 'KYTKYTKYTKYTKYT'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1538904899102064640,
#  'id_str': '1538904899102064640',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'el',
#  'metadata': {'iso_language_code': 'el', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 24,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jun 20 09:24:03 +0000 2022',
#   'entities': {'hashtags': [],
# ...

# %%
for tweet in tweetsZelensky:
    print(tweet['created_at'],tweet['text'])
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
# Sun Jun 19 13:34:01 +0000 2022 Ουκρανία: Αβεβαιότητα για την τύχη των αιχμαλώτων του Αζοφστάλ – Δεν παραδίδουμε το Νότο διαμηνύει ο Ζελένσκι https://t.co/BOPknwwj3b
# Sun Jun 19 13:32:09 +0000 2022 Δεν παραδίδουμε τη Νότια Ουκρανία διαμηνύει ο Ζελένσκι - Αβεβαιότητα για τους αιχμαλώτους του Αζοφστάλ
# https://t.co/8i6E0ILmVZ
# Sun Jun 19 13:24:24 +0000 2022 #Ουκρανία: Αβεβαιότητα για την τύχη των αιχμαλώτων του #Αζοφστάλ – Δεν παραδίδουμε το Νότο διαμηνύει ο #Ζελένσκι https://t.co/J4KEeFQJzT
# Sun Jun 19 13:22:25 +0000 2022 Νομίζει ότι παίζει ακόμη σε σίριαλ - Ζελένσκι: Θα πάρουμε πίσω το νότο! https://t.co/v41obs1Cs9
# Sun Jun 19 13:18:30 +0000 2022 RT @KYTKYTKYTKYTKYT: Καλησπέρες καθίκια μου με μια καινοτομία από τη... Μόσχα με αγάπη στον... "κοιμισμένο Τζο"... 😉🤣
#
# #πουτιν #Russia #Put…
# Sun Jun 19 13:17:23 +0000 2022 RT @simoritis: Η ΕΕ σύντομα, πολύ σύντομα, θα εγκαταλείψει τον Ζελένσκι γτ δεν βγαίνουν τα ''κουκιά''.
# ...

# %%
tweetsZelensky_df = pd.DataFrame(tweetsZelensky)
tweetsZelensky_df.head(5)
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Jun 20 15:21:34 +0000 2022  1538904899102064640  1538904899102064640
# 1  Mon Jun 20 15:12:38 +0000 2022  1538902654575063040  1538902654575063040
# 2  Mon Jun 20 15:11:05 +0000 2022  1538902262537506822  1538902262537506822
# 3  Mon Jun 20 15:06:36 +0000 2022  1538901135871860737  1538901135871860737
# 4  Mon Jun 20 15:06:13 +0000 2022  1538901038329102336  1538901038329102336
#
#                                                 text  truncated  \
# 0  RT @KYTKYTKYTKYTKYT: Υπάρχουν τεράστιες ουρές ...      False
# 1  Ιταλία: Ο Ουκρανός Πρόεδρος Ζελένσκι ζητά την ...      False
# 2  RT @KYTKYTKYTKYTKYT: Υπάρχουν τεράστιες ουρές ...      False
# 3  RT @KYTKYTKYTKYTKYT: Υπάρχουν τεράστιες ουρές ...      False
# 4  RT @sar_iannis: Το ινδαλμα του Δυτικου Κοσμου ...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
file_name = "Final_Tweets_about_Zelensky"

# %%
tweetsZelensky_df.to_csv(f"/content/gdrive/My Drive/Colab Notebooks/Final_Tweets_about_Zelensky.tsv", sep='\t')
